# %%
import numpy as np

from rlofc.ofc_board import OFCBoard
from rlofc.ofc_environment import OFCEnvironment
from rlofc.ofc_agent import OFCRandomAgent, OFCHumanAgent
from rlofc.deck_generator import DeckGenerator

# %%
agent = OFCRandomAgent()

deck = DeckGenerator.new_deck()
board = OFCBoard()

for i in xrange(13):
    draw = deck.pop()
    street_id = agent.place_new_card(draw, board)
    board.place_card_by_id(draw, street_id)

board.pretty()
assert board.is_complete()
# Out:
# Front:
#   [ 8 ♠ ] , [ Q ♦ ] , [ 9 ❤ ]
# Mid:
#   [ 7 ♠ ] , [ 2 ♣ ] , [ 9 ♣ ] , [ J ❤ ] , [ 3 ♣ ]
# Back:
#   [ A ♣ ] , [ 9 ♦ ] , [ K ♣ ] , [ 7 ♣ ] , [ 5 ❤ ]

# %%
lhs = OFCRandomAgent()
rhs = OFCRandomAgent()

ofc_game = OFCEnvironment(lhs, rhs)

score, lhs_board, rhs_board = ofc_game.play_game()
print score
lhs_board.pretty()
rhs_board.pretty()
assert type(score) is int
# Out:
# 0
# Front:
#   [ 5 ♦ ] , [ 9 ❤ ] , [ 9 ♦ ]
# Mid:
#   [ 2 ❤ ] , [ J ♦ ] , [ 5 ❤ ] , [ 3 ♦ ] , [ 9 ♣ ]
# Back:
#   [ 6 ♦ ] , [ Q ♣ ] , [ J ♣ ] , [ 8 ♣ ] , [ K ❤ ]
# Front:
#   [ 6 ♠ ] , [ J ❤ ] , [ 2 ♣ ]
# Mid:
#   [ 3 ♠ ] , [ A ♦ ] , [ 7 ♦ ] , [ T ❤ ] , [ T ♣ ]
# Back:
#   [ 2 ♦ ] , [ 4 ♠ ] , [ T ♠ ] , [ 4 ♦ ] , [ J ♠ ]

# %%
lhs = OFCHumanAgent('Andrew')
rhs = OFCHumanAgent('Jarry')

ofc_game = OFCEnvironment(lhs, rhs)

score, lhs_board, rhs_board = ofc_game.play_game_human_human()
print 'Player 1 score:', score
print 'Player 1 board:'
lhs_board.pretty()
print 'Player 2 board:'
rhs_board.pretty()
assert type(score) is int
# Out:
# Front:
#
# Mid:
#
# Back:
#
# Player 1 starting cards;   [ J ♦ ] , [ 9 ♣ ] , [ 2 ♠ ] , [ 7 ❤ ] , [ Q ❤ ]
# Current card:  [ J ♦ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 1
# Front:
#
# Mid:
#   [ J ♦ ]
# Back:
#
# Current card:  [ 9 ♣ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 0
# Front:
#   [ 9 ♣ ]
# Mid:
#   [ J ♦ ]
# Back:
#
# Current card:  [ 2 ♠ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 0
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ]
# Back:
#
# Current card:  [ 7 ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 2
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ]
# Back:
#   [ 7 ❤ ]
# Current card:  [ Q ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 2
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ]
# Front:
#
# Mid:
#
# Back:
#
# Player 2 starting cards;   [ 5 ♣ ] , [ J ♠ ] , [ Q ♦ ] , [ 4 ♦ ] , [ A ♣ ]
# Current card:  [ 5 ♣ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 2
# Front:
#
# Mid:
#
# Back:
#   [ 5 ♣ ]
# Current card:  [ J ♠ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 0
# Front:
#   [ J ♠ ]
# Mid:
#
# Back:
#   [ 5 ♣ ]
# Current card:  [ Q ♦ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 1
# Front:
#   [ J ♠ ]
# Mid:
#   [ Q ♦ ]
# Back:
#   [ 5 ♣ ]
# Current card:  [ 4 ♦ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 1
# Front:
#   [ J ♠ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ]
# Current card:  [ A ♣ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 2
# Front:
#   [ J ♠ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ]
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ]
#
# Current card:  [ 8 ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 2
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ]
#
# Current card:  [ 9 ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 0
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ]
#
# Current card:  [ Q ♠ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ]
#
# Current card:  [ 7 ♣ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 2
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ]
#
# Current card:  [ 6 ♦ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ]
#
# Current card:  [ 2 ♣ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 2
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ 6 ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 2
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ T ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ 8 ♠ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ K ♦ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ 6 ♠ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Andrew, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ 2 ❤ ]
# Available streets:
# 0: front
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 0
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ] , [ 2 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ 9 ♦ ]
# Available streets:
# 0: front
# 2: back
# Andrew, please enter the street (number) to play your card.
# 0
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ] , [ 9 ♦ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ] , [ 2 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ 7 ♠ ]
# Available streets:
# 1: mid
# 2: back
# Jarry, please enter the street (number) to play your card.
# 1
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ] , [ 9 ♦ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ] , [ 2 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ] , [ 7 ♠ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ J ❤ ]
# Available streets:
# 2: back
# Andrew, please enter the street (number) to play your card.
# 0
# Please enter a valid street: [2]
# 2
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ] , [ 9 ♦ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ] , [ J ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ] , [ 2 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ] , [ 7 ♠ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ]
#
# Current card:  [ T ♦ ]
# Available streets:
# 2: back
# Jarry, please enter the street (number) to play your card.
# 2
# Final Boards
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ] , [ 9 ♦ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ] , [ J ❤ ]
#
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ] , [ 2 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ] , [ 7 ♠ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ] , [ T ♦ ]
#
# Player 1 score: -6
# Player 1 board:
# Front:
#   [ 9 ♣ ] , [ 2 ♠ ] , [ 9 ♦ ]
# Mid:
#   [ J ♦ ] , [ Q ♠ ] , [ 6 ♦ ] , [ 8 ♠ ] , [ 6 ♠ ]
# Back:
#   [ 7 ❤ ] , [ Q ❤ ] , [ 8 ❤ ] , [ 6 ❤ ] , [ J ❤ ]
# Player 2 board:
# Front:
#   [ J ♠ ] , [ 9 ❤ ] , [ 2 ❤ ]
# Mid:
#   [ Q ♦ ] , [ 4 ♦ ] , [ T ❤ ] , [ K ♦ ] , [ 7 ♠ ]
# Back:
#   [ 5 ♣ ] , [ A ♣ ] , [ 7 ♣ ] , [ 2 ♣ ] , [ T ♦ ]

# %%
np.random.uniform(0, 1, 3)
# Out:
# array([0.86383057, 0.49634707, 0.96308962])

# %%
np.where([0, 1, 1] == 0)
# Out:
# (array([], dtype=int64),)

# %%
np.argmax([0, 0, 0])
# Out:
# 0
